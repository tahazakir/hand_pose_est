# %%
# ============================================================================
# CELL 1: SETUP & INSTALLATION
# ============================================================================

import os
from google.colab import drive
import torch

print("="*70)
print("YOLO11-POSE HAND KEYPOINTS TRAINING - SETUP")
print("="*70)

# Mount Google Drive
print("\n[1/4] Mounting Google Drive...")
drive.mount('/content/drive')

# Create output directory
output_dir = '/content/drive/MyDrive/Intro To AI/yolo_hand_pose'
os.makedirs(output_dir, exist_ok=True)
print(f"✓ Output directory: {output_dir}")

# Install Ultralytics
print("\n[2/4] Installing Ultralytics YOLO...")
# !pip install -q ultralytics
print("✓ Ultralytics installed")

# Verify GPU
print("\n[3/4] Checking GPU...")
if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_name(0)
    print(f"✓ GPU Available: {gpu_name}")
    print(f"✓ CUDA Version: {torch.version.cuda}")
    print(f"✓ GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    print("⚠ WARNING: No GPU! Go to Runtime → Change runtime type → T4 GPU")
    raise RuntimeError("GPU required for training")

# Import YOLO
print("\n[4/4] Importing YOLO...")
from ultralytics import YOLO
print("✓ YOLO imported successfully")

print("\n" + "="*70)
print("✅ SETUP COMPLETE! Run Cell 2 for test training.")
print("="*70)
# Out:
# ======================================================================
# YOLO11-POSE HAND KEYPOINTS TRAINING - SETUP
# ======================================================================
#
# [1/4] Mounting Google Drive...
# Mounted at /content/drive
# ✓ Output directory: /content/drive/MyDrive/Intro To AI/yolo_hand_pose
#
# [2/4] Installing Ultralytics YOLO...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 69.2 MB/s eta 0:00:00
# ✓ Ultralytics installed
#
# [3/4] Checking GPU...
# ✓ GPU Available: Tesla T4
# ✓ CUDA Version: 12.6
# ✓ GPU Memory: 15.83 GB
#
# [4/4] Importing YOLO...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✓ YOLO imported successfully
#
# ======================================================================
# ✅ SETUP COMPLETE! Run Cell 2 for test training.
# ======================================================================

# %%
# ============================================================================
# CELL 2: TEST RUN - 2 EPOCHS
# ============================================================================

from ultralytics import YOLO
import os

output_dir = '/content/drive/MyDrive/Intro To AI/yolo_hand_pose'

print("="*70)
print("TEST RUN: 2 EPOCHS")
print("This verifies everything works before full training")
print("="*70)

# Load pretrained model
print("\nLoading yolo11n-pose.pt...")
model = YOLO('yolo11n-pose.pt')

print("\n🧪 Starting test training...")
print("Dataset will auto-download (369 MB) on first run")
print("Expected time: 5-10 minutes")
print("-"*70)

# Test training
test_results = model.train(
    data='hand-keypoints.yaml',      # Auto-downloads dataset
    epochs=2,                         # Just 2 epochs
    imgsz=640,
    batch=16,
    device=0,
    project=output_dir,
    name='test_run',
    exist_ok=True,
    cache=True,                       # Cache for speed
    amp=True,                         # Mixed precision
    workers=2,
    verbose=True,
)

print("\n" + "="*70)
print("✅ TEST RUN SUCCESSFUL!")
print("="*70)
print(f"Test model saved: {output_dir}/test_run/weights/best.pt")
print("\nEverything works! Now run Cell 3 for full training (50 epochs).")
print("="*70)
# Out:
# ======================================================================
# TEST RUN: 2 EPOCHS
# This verifies everything works before full training
# ======================================================================
#
# Loading yolo11n-pose.pt...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n
jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0294      1.0165      1.0311      1.0186      1.0306      1.0136      1.0266]
# val: /content/datasets/hand-keypoints/images/val/IMG_00009669.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0304      1.0184      1.0352      1.0219      1.0358      1.0184       1.033]
# val: /content/datasets/hand-keypoints/images/val/IMG_00009784.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0433]
# val: /content/datasets/hand-keypoints/images/val/IMG_00010145.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0383]
# val: /content/datasets/hand-keypoints/images/val/IMG_00010208.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0278]
# val: /content/datasets/hand-keypoints/images/val/IMG_00010624.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0416]
# val: /content/datasets/hand-keypoints/images/val/IMG_00010625.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0426]
# val: /content/datasets/hand-keypoints/images/val/IMG_00010629.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0776      1.0449]
# val: /content/datasets/hand-keypoints/images/val/IMG_00010630.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0901      1.0618]
# val: /content/datasets/hand-keypoints/images/val/IMG_00010836.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.026      1.0303      1.0448]
# val: /content/datasets/hand-keypoints/images/val/IMG_00011443.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0294]
# val: /content/datasets/hand-keypoints/images/val/IMG_00012734.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0361      1.0111]
# val: /content/datasets/hand-keypoints/images/val/IMG_00013507.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0183]
# val: /content/datasets/hand-keypoints/images/val/IMG_00013511.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.019]
# val: /content/datasets/hand-keypoints/images/val/IMG_00013513.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0222]
# val: /content/datasets/hand-keypoints/images/val/IMG_00014544.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0155      1.0136      1.0122]
# val: /content/datasets/hand-keypoints/images/val/IMG_00015180.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0139       1.014       1.028      1.0373]
# val: /content/datasets/hand-keypoints/images/val/IMG_00015227.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0179      1.0305      1.0362]
# val: /content/datasets/hand-keypoints/images/val/IMG_00016736.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0208]
# val: /content/datasets/hand-keypoints/images/val/IMG_00016737.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0265]
# val: /content/datasets/hand-keypoints/images/val/IMG_00016738.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0408      1.0113]
# val: /content/datasets/hand-keypoints/images/val/IMG_00016855.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0467      1.0238]
# val: /content/datasets/hand-keypoints/images/val/IMG_00016859.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0646]
# val: /content/datasets/hand-keypoints/images/val/IMG_00017306.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0721      1.0198]
# val: /content/datasets/hand-keypoints/images/val/IMG_00018650.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0335]
# val: /content/datasets/hand-keypoints/images/val/IMG_00018652.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0171]
# val: /content/datasets/hand-keypoints/images/val/IMG_00018940.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0196]
# val: /content/datasets/hand-keypoints/images/val/IMG_00019286.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0141]
# val: /content/datasets/hand-keypoints/images/val/IMG_00019288.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.012]
# val: /content/datasets/hand-keypoints/images/val/IMG_00020313.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0136      1.0309]
# val: /content/datasets/hand-keypoints/images/val/IMG_00020605.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0286      1.0169]
# val: /content/datasets/hand-keypoints/images/val/IMG_00020610.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1015      1.0391]
# val: /content/datasets/hand-keypoints/images/val/IMG_00021089.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0222]
# val: /content/datasets/hand-keypoints/images/val/IMG_00021090.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0269]
# val: /content/datasets/hand-keypoints/images/val/IMG_00022171.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0388      1.0178]
# val: /content/datasets/hand-keypoints/images/val/IMG_00022316.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0503      1.0218]
# val: /content/datasets/hand-keypoints/images/val/IMG_00022319.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0913      1.0549]
# val: /content/datasets/hand-keypoints/images/val/IMG_00022320.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.105      1.0617]
# val: /content/datasets/hand-keypoints/images/val/IMG_00023759.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0125]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024545.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0167]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024568.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0195]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024670.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0176      1.0662       1.115]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024674.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0295      1.0714      1.1099]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024715.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0325      1.0847]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024725.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0152       1.056]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024726.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0372      1.0936]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024915.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0348]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025165.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0215]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025227.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0277]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025243.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0294]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025367.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0583      1.0963]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025411.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0947      1.0339]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025492.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0107]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025493.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0198]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025501.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0143]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025610.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.02      1.0758      1.1245]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025669.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0228]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025785.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0138]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025962.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0764]
# val: /content/datasets/hand-keypoints/images/val/IMG_00026254.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0257]
# val: /content/datasets/hand-keypoints/images/val/IMG_00026255.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0264]
# val: /content/datasets/hand-keypoints/images/val/IMG_00026507.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0183]
# val: /content/datasets/hand-keypoints/images/val/IMG_00026508.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0182]
# val: /content/datasets/hand-keypoints/images/val/IMG_00026821.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0395]
# val: /content/datasets/hand-keypoints/images/val/IMG_00026823.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.032]
# val: /content/datasets/hand-keypoints/images/val/IMG_00027080.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0135]
# val: /content/datasets/hand-keypoints/images/val/IMG_00027976.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0408      1.0878]
# val: /content/datasets/hand-keypoints/images/val/IMG_00027994.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0138]
# val: /content/datasets/hand-keypoints/images/val/IMG_00034349.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0249]
# val: /content/datasets/hand-keypoints/images/val/IMG_00034527.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0115]
# val: /content/datasets/hand-keypoints/images/val/IMG_00034962.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0867]
# val: /content/datasets/hand-keypoints/images/val/IMG_00035055.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0369]
# val: /content/datasets/hand-keypoints/images/val/IMG_00035057.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0388]
# val: /content/datasets/hand-keypoints/images/val/IMG_00035059.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0393]
# val: /content/datasets/hand-keypoints/images/val/IMG_00035123.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0529]
# val: /content/datasets/hand-keypoints/images/val/IMG_00035125.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0406]
# val: /content/datasets/hand-keypoints/images/val/IMG_00035439.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0209]
# val: New cache created: /content/datasets/hand-keypoints/labels/val.cache
# WARNING ⚠️ val: 13.5GB RAM required to cache images with 50% safety margin but only 9.6/12.7GB available, not caching images
# Plotting labels to /content/drive/MyDrive/Intro To AI/yolo_hand_pose/test_run/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 87 weight(decay=0.0), 97 weight(decay=0.0005), 96 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/Intro To AI/yolo_hand_pose/test_run
# Starting training for 2 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#         1/2       2.5G      1.027       8.68     0.5725     0.7977      1.356         19        640: 100% ━━━━━━━━━━━━ 1150/1150 2.6it/s 7:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 246/246 2.9it/s 1:25
#                    all       7847       7847      0.843      0.622      0.785      0.567      0.308      0.167     0.0641     0.0134
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#         2/2      2.91G     0.8976      6.479     0.4289     0.6209      1.254         16        640: 100% ━━━━━━━━━━━━ 1150/1150 2.8it/s 6:45
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 246/246 3.1it/s 1:19
#                    all       7847       7847      0.928      0.928      0.973      0.763       0.75      0.484      0.482      0.203
#
# 2 epochs completed in 0.281 hours.
# Optimizer stripped from /content/drive/MyDrive/Intro To AI/yolo_hand_pose/test_run/weights/last.pt, 6.2MB
# Optimizer stripped from /content/drive/MyDrive/Intro To AI/yolo_hand_pose/test_run/weights/best.pt, 6.2MB
#
# Validating /content/drive/MyDrive/Intro To AI/yolo_hand_pose/test_run/weights/best.pt...
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-pose summary (fused): 109 layers, 2,956,000 parameters, 0 gradients, 7.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 246/246 3.0it/s 1:21
#                    all       7847       7847      0.928      0.929      0.973      0.763       0.75      0.484      0.482      0.203
# Speed: 0.2ms preprocess, 2.4ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to /content/drive/MyDrive/Intro To AI/yolo_hand_pose/test_run
#
# ======================================================================
# ✅ TEST RUN SUCCESSFUL!
# ======================================================================
# Test model saved: /content/drive/MyDrive/Intro To AI/yolo_hand_pose/test_run/weights/best.pt
#
# Everything works! Now run Cell 3 for full training (50 epochs).
# ======================================================================

# %%
# ============================================================================
# CELL 3: FULL TRAINING - 50 EPOCHS (~90-120 minutes)
# ============================================================================

from ultralytics import YOLO
import os
from datetime import datetime

output_dir = '/content/drive/MyDrive/Intro To AI/yolo_hand_pose'

print("="*70)
print("FULL TRAINING: 50 EPOCHS")
print("="*70)
print(f"Start time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("Estimated duration: 90-120 minutes on T4 GPU")
print("="*70)

# Load fresh pretrained model
print("\nLoading yolo11n-pose.pt...")
model = YOLO('yolo11n-pose.pt')

print("\n🚀 Starting full training...")
print("-"*70)

# Full training
results = model.train(
    data='hand-keypoints.yaml',
    epochs=30,
    imgsz=640,
    batch=16,
    device=0,
    project=output_dir,
    name='hand_pose_full',
    exist_ok=True,
    cache=True,
    amp=True,
    workers=4,
    patience=10,
    save_period=2,
    verbose=True,
    plots=True,
)

# ============================================================================
# EXPORT MODELS FOR MACBOOK DEPLOYMENT
# ============================================================================
print("\n" + "="*70)
print("EXPORTING MODELS FOR DEPLOYMENT")
print("="*70)

best_model_path = f"{output_dir}/hand_pose_full/weights/best.pt"
model = YOLO(best_model_path)

# Export 1: CoreML (optimized for MacBook/Apple Silicon)
print("\n[1/2] Exporting to CoreML format (for MacBook)...")
try:
    coreml_path = model.export(format='coreml')
    print(f"✅ CoreML model: {coreml_path}")
    print("    → Best for MacBook M1/M2/M3 (uses Neural Engine)")
except Exception as e:
    print(f"⚠️  CoreML export failed: {e}")

# Export 2: ONNX (cross-platform)
print("\n[2/2] Exporting to ONNX format (cross-platform)...")
try:
    onnx_path = model.export(format='onnx')
    print(f"✅ ONNX model: {onnx_path}")
    print("    → Works on Mac/Windows/Linux")
except Exception as e:
    print(f"⚠️  ONNX export failed: {e}")

# ============================================================================
# TRAINING COMPLETE
# ============================================================================
print("\n" + "="*70)
print("TRAINING & EXPORT COMPLETE!")
print("="*70)

# Display metrics
if hasattr(results, 'results_dict'):
    print("\nFINAL METRICS:")
    for key, value in results.results_dict.items():
        if 'mAP' in key or 'precision' in key or 'recall' in key:
            print(f"  {key}: {value:.4f}")

# File summary
print("\n" + "="*70)
print("FILES IN GOOGLE DRIVE")
print("="*70)
print(f"📁 {output_dir}/hand_pose_full/")
print(f"   ├── weights/")
print(f"   │   ├── best.pt           ⬅ PyTorch model")
print(f"   │   ├── best.mlpackage/   ⬅ CoreML for MacBook ⭐")
print(f"   │   ├── best.onnx         ⬅ ONNX cross-platform")
print(f"   │   └── last.pt           (for resuming)")
print(f"   ├── results.png")
print(f"   └── confusion_matrix.png")

print("\n💡 FOR MACBOOK: Download 'best.mlpackage' folder")
print("   (CoreML is optimized for Apple Silicon)")
print("\n✅ Go to Google Drive and download your models!")
print(f"End time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("="*70)

# %%
# ============================================================================
# CELL 4: RESUME TRAINING FROM CHECKPOINT
# ============================================================================

from google.colab import drive
from ultralytics import YOLO
import torch

print("="*70)
print("RESUMING TRAINING FROM CHECKPOINT")
print("="*70)

# Mount Drive
print("\n[1/3] Mounting Google Drive...")
drive.mount('/content/drive')

# Verify GPU
print("\n[2/3] Checking GPU...")
if torch.cuda.is_available():
    print(f"✓ GPU: {torch.cuda.get_device_name(0)}")
else:
    raise RuntimeError("GPU required!")

# Resume training
print("\n[3/3] Resuming from last checkpoint...")
output_dir = '/content/drive/MyDrive/Intro To AI/yolo_hand_pose'
checkpoint_path = f'{output_dir}/hand_pose_full/weights/last.pt'

print(f"Loading: {checkpoint_path}")

# Load checkpoint and resume
model = YOLO(checkpoint_path)
results = model.train(resume=True)  # Automatically continues from where it stopped

print("\n✅ Training resumed and completed!")
# Out:
# ======================================================================
# RESUMING TRAINING FROM CHECKPOINT
# ======================================================================
#
# [1/3] Mounting Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# [2/3] Checking GPU...
# ✓ GPU: Tesla T4
#
# [3/3] Resuming from last checkpoint...
# Loading: /content/drive/MyDrive/Intro To AI/yolo_hand_pose/hand_pose_full/weights/last.pt
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/datasets/hand-keypoints.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/Intro To AI/yolo_hand_pose/hand_pose_full/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=hand_pose_full, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/Intro To AI/yolo_hand_pose, rect=False, resume=/content/drive/MyDrive/Intro To AI/yolo_hand_pose/hand_pose_full/weights/last.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/Intro To AI/yolo_hand_pose/hand_pose_full, save_frames=False, save_json=False, save_period=2, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
#
# WARNING ⚠️ Dataset '/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/datasets/hand-keypoints.yaml' images not found, missing path '/content/datasets/hand-keypoints/images/val'
# Downloading https://ultralytics.com/assets/hand-keypoints.zip to '/content/datasets/hand-keypoints.zip': 100% ━━━━━━━━━━━━ 369.0MB 6.8MB/s 54.6s
# Unzipping /content/datasets/hand-keypoints.zip to /content/datasets/hand-keypoints...: 100% ━━━━━━━━━━━━ 53543/53543 5.4Kfiles/s 9.9s
# Dataset download success ✅ (65.7s), saved to /content/datasets
#
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 97.1MB/s 0.0s
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    804898  ultralytics.nn.modules.head.Pose             [1, [21, 3], [64, 128, 256]]
# YOLO11n-pose summary: 196 layers, 2,964,066 parameters, 2,964,050 gradients, 7.9 GFLOPs
#
# Transferred 541/541 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 294.5MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 407.2±191.5 MB/s, size: 12.4 KB)
# train: Scanning /content/datasets/hand-keypoints/labels/train... 18776 images, 0 backgrounds, 384 corrupt: 100% ━━━━━━━━━━━━ 18776/18776 1.2Kit/s 16.3s
# train: /content/datasets/hand-keypoints/images/train/IMG_00001070.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0379]
# train: /content/datasets/hand-keypoints/images/train/IMG_00001886.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0114]
# train: /content/datasets/hand-keypoints/images/train/IMG_00001887.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0121]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002001.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0146]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002002.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0178]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002003.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0178]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002143.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0582      1.0216]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002144.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0641      1.0333]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002202.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0108      1.0112      1.0116]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002451.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0121]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002454.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.023]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002744.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0159]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002745.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0334]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002746.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0399]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002747.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0453]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002749.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0701       1.011]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002751.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0658      1.0113]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002752.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0505]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002754.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0313]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002760.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0266]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002761.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0449]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003001.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0211      1.0371      1.0143      1.0292      1.0175]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003109.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0766      1.0215]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003111.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0615]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003114.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0173]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003162.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0111      1.0368]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003164.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0238      1.0125      1.0397        1.01      1.0396      1.0152]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003372.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0101]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003385.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0125       1.027      1.0279      1.0451      1.0597]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003387.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0227      1.0413      1.0243      1.0437      1.0603]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003388.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0187      1.0366      1.0213       1.039      1.0546]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003390.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0208      1.0405      1.0225      1.0423      1.0603]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003391.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0217       1.012      1.0306      1.0467]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003392.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.016      1.0274      1.0465]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003393.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0219]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003434.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0763      1.0129]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003438.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0473]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003439.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0106]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003440.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0347]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003442.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.018]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003444.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0436      1.0107]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003592.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0162]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003593.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0155      1.0172      1.0174]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003653.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.016]
# train: /content/datasets/hand-keypoints/images/train/IMG_00

# train: /content/datasets/hand-keypoints/images/train/IMG_00017309.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0723      1.0346]
# train: /content/datasets/hand-keypoints/images/train/IMG_00017310.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0717      1.0325]
# train: /content/datasets/hand-keypoints/images/train/IMG_00017756.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0104]
# train: /content/datasets/hand-keypoints/images/train/IMG_00018086.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0191]
# train: /content/datasets/hand-keypoints/images/train/IMG_00018647.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0362]
# train: /content/datasets/hand-keypoints/images/train/IMG_00018648.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0479]
# train: /content/datasets/hand-keypoints/images/train/IMG_00018649.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0437      1.0106]
# train: /content/datasets/hand-keypoints/images/train/IMG_00018651.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.014]
# train: /content/datasets/hand-keypoints/images/train/IMG_00018655.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0164]
# train: /content/datasets/hand-keypoints/images/train/IMG_00018657.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0113]
# train: /content/datasets/hand-keypoints/images/train/IMG_00018658.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0252]
# train: /content/datasets/hand-keypoints/images/train/IMG_00018740.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0212]
# train: /content/datasets/hand-keypoints/images/train/IMG_00018741.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0447]
# train: /content/datasets/hand-keypoints/images/train/IMG_00018742.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0442]
# ...
# val: /content/datasets/hand-keypoints/images/val/IMG_00010208.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0278]
# val: /content/datasets/hand-keypoints/images/val/IMG_00010624.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0416]
# val: /content/datasets/hand-keypoints/images/val/IMG_00010625.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0426]
# val: /content/datasets/hand-keypoints/images/val/IMG_00010629.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0776      1.0449]
# val: /content/datasets/hand-keypoints/images/val/IMG_00010630.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0901      1.0618]
# val: /content/datasets/hand-keypoints/images/val/IMG_00010836.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.026      1.0303      1.0448]
# val: /content/datasets/hand-keypoints/images/val/IMG_00011443.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0294]
# val: /content/datasets/hand-keypoints/images/val/IMG_00012734.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0361      1.0111]
# val: /content/datasets/hand-keypoints/images/val/IMG_00013507.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0183]
# val: /content/datasets/hand-keypoints/images/val/IMG_00013511.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.019]
# val: /content/datasets/hand-keypoints/images/val/IMG_00013513.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0222]
# val: /content/datasets/hand-keypoints/images/val/IMG_00014544.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0155      1.0136      1.0122]
# val: /content/datasets/hand-keypoints/images/val/IMG_00015180.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0139       1.014       1.028      1.0373]
# val: /content/datasets/hand-keypoints/images/val/IMG_00015227.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0179      1.0305      1.0362]
# val: /content/datasets/hand-keypoints/images/val/IMG_00016736.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0208]
# val: /content/datasets/hand-keypoints/images/val/IMG_00016737.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0265]
# val: /content/datasets/hand-keypoints/images/val/IMG_00016738.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0408      1.0113]
# val: /content/datasets/hand-keypoints/images/val/IMG_00016855.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0467      1.0238]
# val: /content/datasets/hand-keypoints/images/val/IMG_00016859.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0646]
# val: /content/datasets/hand-keypoints/images/val/IMG_00017306.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0721      1.0198]
# val: /content/datasets/hand-keypoints/images/val/IMG_00018650.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0335]
# val: /content/datasets/hand-keypoints/images/val/IMG_00018652.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0171]
# val: /content/datasets/hand-keypoints/images/val/IMG_00018940.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0196]
# val: /content/datasets/hand-keypoints/images/val/IMG_00019286.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0141]
# val: /content/datasets/hand-keypoints/images/val/IMG_00019288.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.012]
# val: /content/datasets/hand-keypoints/images/val/IMG_00020313.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0136      1.0309]
# val: /content/datasets/hand-keypoints/images/val/IMG_00020605.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0286      1.0169]
# val: /content/datasets/hand-keypoints/images/val/IMG_00020610.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1015      1.0391]
# val: /content/datasets/hand-keypoints/images/val/IMG_00021089.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0222]
# val: /content/datasets/hand-keypoints/images/val/IMG_00021090.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0269]
# val: /content/datasets/hand-keypoints/images/val/IMG_00022171.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0388      1.0178]
# val: /content/datasets/hand-keypoints/images/val/IMG_00022316.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0503      1.0218]
# val: /content/datasets/hand-keypoints/images/val/IMG_00022319.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0913      1.0549]
# val: /content/datasets/hand-keypoints/images/val/IMG_00022320.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.105      1.0617]
# val: /content/datasets/hand-keypoints/images/val/IMG_00023759.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0125]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024545.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0167]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024568.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0195]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024670.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0176      1.0662       1.115]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024674.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0295      1.0714      1.1099]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024715.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0325      1.0847]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024725.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0152       1.056]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024726.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0372      1.0936]
# val: /content/datasets/hand-keypoints/images/val/IMG_00024915.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0348]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025165.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0215]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025227.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0277]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025243.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0294]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025367.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0583      1.0963]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025411.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0947      1.0339]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025492.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0107]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025493.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0198]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025501.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0143]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025610.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.02      1.0758      1.1245]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025669.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0228]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025785.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0138]
# val: /content/datasets/hand-keypoints/images/val/IMG_00025962.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0764]
# val: /content/datasets/hand-keypoints/images/val/IMG_00026254.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0257]
# val: /content/datasets/hand-keypoints/images/val/IMG_00026255.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0264]
# val: /content/datasets/hand-keypoints/images/val/IMG_00026507.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0183]
# val: /content/datasets/hand-keypoints/images/val/IMG_00026508.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0182]
# val: /content/datasets/hand-keypoints/images/val/IMG_00026821.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0395]
# val: /content/datasets/hand-keypoints/images/val/IMG_00026823.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.032]
# val: /content/datasets/hand-keypoints/images/val/IMG_00027080.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0135]
# val: /content/datasets/hand-keypoints/images/val/IMG_00027976.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0408      1.0878]
# val: /content/datasets/hand-keypoints/images/val/IMG_00027994.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0138]
# val: /content/datasets/hand-keypoints/images/val/IMG_00034349.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0249]
# val: /content/datasets/hand-keypoints/images/val/IMG_00034527.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0115]
# val: /content/datasets/hand-keypoints/images/val/IMG_00034962.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0867]
# val: /content/datasets/hand-keypoints/images/val/IMG_00035055.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0369]
# val: /content/datasets/hand-keypoints/images/val/IMG_00035057.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0388]
# val: /content/datasets/hand-keypoints/images/val/IMG_00035059.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0393]
# val: /content/datasets/hand-keypoints/images/val/IMG_00035123.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0529]
# val: /content/datasets/hand-keypoints/images/val/IMG_00035125.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0406]
# val: /content/datasets/hand-keypoints/images/val/IMG_00035439.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0209]
# val: New cache created: /content/datasets/hand-keypoints/labels/val.cache
# WARNING ⚠️ val: 13.5GB RAM required to cache images with 50% safety margin but only 9.7/12.7GB available, not caching images
# Plotting labels to /content/drive/MyDrive/Intro To AI/yolo_hand_pose/hand_pose_full/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 87 weight(decay=0.0), 97 weight(decay=0.0005), 96 bias(decay=0.0)
# Resuming training /content/drive/MyDrive/Intro To AI/yolo_hand_pose/hand_pose_full/weights/last.pt from epoch 21 to 30 total epochs
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/Intro To AI/yolo_hand_pose/hand_pose_full
# Starting training for 30 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       21/30       2.6G     0.5801        nan        nan     0.3182      1.084          7        640: 100% ━━━━━━━━━━━━ 1150/1150 3.2it/s 5:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 246/246 3.3it/s 1:14
#                    all       7847       7847       0.97      0.977      0.991      0.882      0.845      0.798      0.823      0.655
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      3.01G        nan        nan        nan        nan        nan          8        640: 100% ━━━━━━━━━━━━ 1150/1150 3.5it/s 5:32
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 246/246 4.9it/s 50.1s
#                    all       7847       7847          0          0          0          0          0          0          0          0
# WARNING ⚠️ Loss NaN/Inf detected (attempt 1/3), recovering from last.pt...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-2665335334.py in <cell line: 0>()
#      31 # Load checkpoint and resume
#      32 model = YOLO(checkpoint_path)
# ---> 33 results = model.train(resume=True)  # Automatically continues from where it stopped
#      34
#      35 print("\n✅ Training resumed and completed!")
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     776             self.model = self.trainer.model
#     777
# --> 778         self.trainer.train()
#     779         # Update model and cfg after training
#     780         if RANK in {-1, 0}:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in train(self)
#     241
#     242         else:
# --> 243             self._do_train()
#     244
#     245     def _setup_scheduler(self):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in _do_train(self)
#     479
#     480             # NaN recovery
# --> 481             if self._handle_nan_recovery(epoch):
#     482                 continue
#     483
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in _handle_nan_recovery(self, epoch)
#     870         ema_state = ckpt["ema"].float().state_dict()
#     871         if not all(torch.isfinite(v).all() for v in ema_state.values() if isinstance(v, torch.Tensor)):
# --> 872             raise RuntimeError(f"Checkpoint {self.last} is corrupted with NaN/Inf weights")
#     873         unwrap_model(self.model).load_state_dict(ema_state)  # Load EMA weights into model
#     874         self._load_checkpoint_state(ckpt)  # Load optimizer/scaler/EMA/best_fitness
#
# RuntimeError: Checkpoint /content/drive/MyDrive/Intro To AI/yolo_hand_pose/hand_pose_full/weights/last.pt is corrupted with NaN/Inf weights

# %%
# !ls -lh /content/drive/MyDrive/Intro\ To\ AI/yolo_hand_pose/hand_pose_full/weights/
# Out:
# total 228M
# -rw------- 1 root root 18M Nov  8 20:34 best.pt
# -rw------- 1 root root 18M Nov  7 20:24 epoch0.pt
# -rw------- 1 root root 18M Nov  8 17:36 epoch10.pt
# -rw------- 1 root root 18M Nov  8 17:50 epoch12.pt
# -rw------- 1 root root 18M Nov  8 18:03 epoch14.pt
# -rw------- 1 root root 18M Nov  8 18:16 epoch16.pt
# -rw------- 1 root root 18M Nov  8 18:30 epoch18.pt
# -rw------- 1 root root 18M Nov  8 20:34 epoch20.pt
# -rw------- 1 root root 18M Nov  7 20:41 epoch2.pt
# -rw------- 1 root root 18M Nov  8 16:34 epoch4.pt
# -rw------- 1 root root 18M Nov  8 16:59 epoch6.pt
# -rw------- 1 root root 18M Nov  8 17:23 epoch8.pt
# -rw------- 1 root root 18M Nov  8 20:34 last.pt

# %%
# ============================================================================
# RESUME FROM BEST.PT (SAFE CHECKPOINT BEFORE NaN)
# ============================================================================

from google.colab import drive
from ultralytics import YOLO
import torch

print("="*70)
print("RESUMING FROM EPOCH 20 (best.pt)")
print("="*70)

# Mount Drive
drive.mount('/content/drive')

# Verify GPU
if torch.cuda.is_available():
    print(f"✓ GPU: {torch.cuda.get_device_name(0)}")
else:
    raise RuntimeError("GPU required!")

# Load the best checkpoint (from epoch 20, before corruption)
output_dir = '/content/drive/MyDrive/Intro To AI/yolo_hand_pose'
checkpoint_path = f'{output_dir}/hand_pose_full/weights/best.pt'

print(f"\nLoading: {checkpoint_path}")
print("This was your best model before the NaN error at epoch 21")

model = YOLO(checkpoint_path)

print("\n🚀 Resuming training with NaN prevention settings...")
print("Changes from original:")
print("  • Lower learning rate (0.0005 instead of 0.002)")
print("  • Mixed precision disabled (more stable)")
print("  • Training to epoch 30")
print("-"*70)

# Resume training with stable settings
results = model.train(
    data='hand-keypoints.yaml',
    epochs=30,                    # Continue to epoch 30
    imgsz=640,
    batch=16,
    device=0,
    project=output_dir,
    name='hand_pose_full',
    exist_ok=True,

    # NaN Prevention Settings
    lr0=0.0005,                   # Lower learning rate (was 0.002)
    lrf=0.01,                     # Lower final learning rate
    warmup_epochs=2,              # Gradual warmup
    amp=False,                    # Disable mixed precision for stability

    # Regular settings
    cache=True,
    workers=2,
    patience=15,                  # Increased patience
    save_period=2,                # Keep saving every 2 epochs
    verbose=True,
    plots=True,
)

# Export models after completion
print("\n" + "="*70)
print("EXPORTING MODELS")
print("="*70)

best_model = YOLO(f'{output_dir}/hand_pose_full/weights/best.pt')

# Export CoreML for MacBook
print("\n[1/2] Exporting to CoreML...")
try:
    coreml_path = best_model.export(format='coreml')
    print(f"✅ CoreML: {coreml_path}")
except Exception as e:
    print(f"⚠️  CoreML failed: {e}")

# Export ONNX
print("\n[2/2] Exporting to ONNX...")
try:
    onnx_path = best_model.export(format='onnx')
    print(f"✅ ONNX: {onnx_path}")
except Exception as e:
    print(f"⚠️  ONNX failed: {e}")

print("\n" + "="*70)
print("✅ TRAINING COMPLETE!")
print("="*70)
print(f"Models saved in: {output_dir}/hand_pose_full/weights/")
print("  • best.pt (PyTorch)")
print("  • best.mlpackage/ (CoreML for MacBook)")
print("  • best.onnx (cross-platform)")
print("="*70)
# Out:
# ======================================================================
# RESUMING FROM EPOCH 20 (best.pt)
# ======================================================================
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✓ GPU: Tesla T4
#
# Loading: /content/drive/MyDrive/Intro To AI/yolo_hand_pose/hand_pose_full/weights/best.pt
# This was your best model before the NaN error at epoch 21
#
# 🚀 Resuming training with NaN prevention settings...
# Changes from original:
#   • Lower learning rate (0.0005 instead of 0.002)
#   • Mixed precision disabled (more stable)
#   • Training to epoch 30
# ----------------------------------------------------------------------
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=False, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=hand-keypoints.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/Intro To AI/yolo_hand_pose/hand_pose_full/weights/best.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=hand_pose_full, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/Intro To AI/yolo_hand_pose, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/Intro To AI/yolo_hand_pose/hand_pose_full, save_frames=False, save_json=False, save_period=2, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=2, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    804898  ultralytics.nn.modules.head.Pose             [1, [21, 3], [64, 128, 256]]
# YOLO11n-pose summary: 196 layers, 2,964,066 parameters, 2,964,050 gradients, 7.9 GFLOPs
#
# Transferred 541/541 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 686.6±326.7 MB/s, size: 12.5 KB)
# train: Scanning /content/datasets/hand-keypoints/labels/train.cache... 18776 images, 0 backgrounds, 384 corrupt: 100% ━━━━━━━━━━━━ 18776/18776 24.7Mit/s 0.0s
# train: /content/datasets/hand-keypoints/images/train/IMG_00001070.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0379]
# train: /content/datasets/hand-keypoints/images/train/IMG_00001886.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0114]
# train: /content/datasets/hand-keypoints/images/train/IMG_00001887.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0121]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002001.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0146]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002002.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0178]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002003.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0178]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002143.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0582      1.0216]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002144.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0641      1.0333]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002202.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0108      1.0112      1.0116]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002451.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0121]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002454.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.023]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002744.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0159]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002745.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0334]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002746.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0399]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002747.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0453]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002749.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0701       1.011]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002751.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0658      1.0113]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002752.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0505]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002754.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0313]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002760.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0266]
# train: /content/datasets/hand-keypoints/images/train/IMG_00002761.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0449]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003001.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0211      1.0371      1.0143      1.0292      1.0175]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003109.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0766      1.0215]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003111.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0615]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003114.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0173]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003162.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0111      1.0368]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003164.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0238      1.0125      1.0397        1.01      1.0396      1.0152]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003372.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0101]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003385.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0125       1.027      1.0279      1.0451      1.0597]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003387.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0227      1.0413      1.0243      1.0437      1.0603]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003388.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0187      1.0366      1.0213       1.039      1.0546]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003390.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0208      1.0405      1.0225      1.0423      1.0603]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003391.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0217       1.012      1.0306      1.0467]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003392.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.016      1.0274      1.0465]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003393.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0219]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003434.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0763      1.0129]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003438.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0473]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003439.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0106]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003440.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0347]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003442.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.018]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003444.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0436      1.0107]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003592.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0162]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003593.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0155      1.0172      1.0174]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003653.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.016]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003654.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0179]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003738.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0135      1.0192]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003739.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0169      1.0193      1.0201      1.0166]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003852.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0196      1.0118      1.0866      1.1344      1.1761]
# train: /content/datasets/hand-keypoints/images/train/IMG_00003853.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1